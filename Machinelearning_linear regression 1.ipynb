# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("C:/Users/91790/Downloads/homeprices.csv")

# %%
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#%matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area, df.price, color='red', marker = '+')
#To plot with predicted val
plt.plot(df.area,reg.predict(df[['area']]))

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict(np.array([[3300]]))
# Out:
# C:\Users\91790\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
d = pd.read_csv("C:/Users/91790/Downloads/areas.csv")

# %% [markdown]
# Import another CSV file of available areas and predict their prices

# %%
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p = reg.predict(d)

# %%
d['prices'] = p

# %%
d

# %%
Add the predicted price directly to the csv file

# %%
d.to_csv("areas.csv")
